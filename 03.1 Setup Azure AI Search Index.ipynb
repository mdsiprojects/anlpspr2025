# %%
from IPython.display import Markdown, display

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".openaidev.env")
# Out:
# True

# %% [markdown]
# # Search

# %%
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.core.credentials import AzureKeyCredential
import os

# %%
load_dotenv(override=True) # take environment variables from .env.

# Variables not used here do not need to be updated in your .env file
endpoint = os.environ["AZURE_SEARCH_SERVICE_ENDPOINT"]
credential = AzureKeyCredential(os.environ["AZURE_SEARCH_ADMIN_KEY"]) if len(os.environ["AZURE_SEARCH_ADMIN_KEY"]) > 0 else DefaultAzureCredential()
index_name = os.environ["AZURE_SEARCH_INDEX"]

# %%
from azure.search.documents.indexes import SearchIndexClient
from azure.search.documents.indexes.models import (
    SearchField,
    SearchFieldDataType,
    VectorSearch,
    HnswAlgorithmConfiguration,
    HnswParameters,
    VectorSearchAlgorithmMetric,
    ExhaustiveKnnAlgorithmConfiguration,
    ExhaustiveKnnParameters,

    VectorSearchProfile,
    SemanticConfiguration,
    SemanticSearch,
    SemanticPrioritizedFields,
    SemanticField,
    SearchIndex
)

# Create a search index
# Fields of type Edm.String or Collection(Edm.String) are searchable by default
index_client = SearchIndexClient(endpoint=endpoint, credential=credential)
fields = [
    SearchField(name="chunk_id", type=SearchFieldDataType.String, key=True, sortable=True, filterable=True, facetable=True, analyzer_name="keyword"),
    SearchField(name="file_name", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
    SearchField(name="base_name", type=SearchFieldDataType.String, sortable=True, filterable=True, facetable=True),
    SearchField(name="content", type=SearchFieldDataType.String, sortable=False, filterable=False, facetable=False, analyzer_name="en.microsoft"),
    # Vector fields must be searchable and retrievable, but they can't be filterable, facetable, or sortable.
    # Vector fields are indexed using algorithms specified in a vector search profile
    SearchField(
        name="content_vector",
        searchable=True,
        filterable=False,
        facetable=False,
        sortable=False,
        type=SearchFieldDataType.Collection(SearchFieldDataType.Single),
        vector_search_dimensions=1536,
        vector_search_profile_name="myHnswProfile"),
]

# Configure the vector search configuration
vector_search = VectorSearch(
    algorithms=[
        HnswAlgorithmConfiguration(
            name="myHnsw",
            parameters=HnswParameters(
                m=4,
                ef_construction=400,
                ef_search=500,
                metric=VectorSearchAlgorithmMetric.COSINE,
            ),
        ),
        ExhaustiveKnnAlgorithmConfiguration(
            name="myExhaustiveKnn",
            parameters=ExhaustiveKnnParameters(
                metric=VectorSearchAlgorithmMetric.COSINE,
            ),
        ),
    ],
    profiles=[
        VectorSearchProfile(
            name="myHnswProfile",
            algorithm_configuration_name="myHnsw",
            # vectorizer="myOpenAI",
        ),
        VectorSearchProfile(
            name="myExhaustiveKnnProfile",
            algorithm_configuration_name="myExhaustiveKnn",
            # vectorizer="myOpenAI",
        ),
    ],
    # vectorizers=[
    #     AzureOpenAIVectorizer(
    #         name="myOpenAI",
    #         kind="azureOpenAI",
    #         azure_open_ai_parameters=AzureOpenAIParameters(
    #             resource_uri=azure_openai_endpoint,
    #             deployment_id=azure_openai_embedding_deployment,
    #             api_key=azure_openai_key,
    #         ),
    #     ),
    # ],
)

semantic_config = SemanticConfiguration(
    name="my-semantic-config",
    prioritized_fields=SemanticPrioritizedFields(
        title_field=SemanticField(field_name="base_name"),
        content_fields=[SemanticField(field_name="content")]
    ),
)

# Create the semantic search with the configuration -- not available for free tier
semantic_search = SemanticSearch(configurations=[semantic_config])

# Create the search index
index = SearchIndex(name=index_name, fields=fields, vector_search=vector_search, semantic_search=semantic_search)
result = index_client.create_or_update_index(index)
print(f"{result.name} created")
# Out:
# anlp created

# %% [markdown]
# ## Indexing
#
# https://github.com/Azure/azure-search-vector-samples/blob/main/demo-python/code/basic-vector-workflow/azure-search-vector-python-sample.ipynb
#
#
# https://learn.microsoft.com/en-us/python/api/overview/azure/search-documents-readme?view=azure-python
#
# https://learn.microsoft.com/en-us/python/api/overview/azure/search-documents-readme?view=azure-python#adding-documents-to-your-index

# %%
# DOCUMENT = {
#     "category": "Hotel",
#     "hotelId": "1000",
#     "rating": 4.0,
#     "rooms": [],
#     "hotelName": "Azure Inn",
# }

# # https://learn.microsoft.com/en-us/rest/api/searchservice/addupdate-or-delete-documents#request-body
# result = search_client.upload_documents(documents=[DOCUMENT])

# print("Upload of new document succeeded: {}".format(result[0].succeeded))

# %% [markdown]
# ### OR

# %%
import json

def load_json_files(folder_path):
    documents = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith(".json"):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, "r", encoding="utf-8") as file:
                try:
                    # Load JSON content
                    document = json.load(file)
                    # Add document to the buffered sender
                    documents.append(document)
                    print(f"loaded document from {file_name}")
                except Exception as e:
                    print(f"Failed to index document from {file_name}: {e}")
    return documents

# %%
documents = load_json_files("./data/documents/search_json")
print(type(documents))
# Out:
# loaded document from Benefit_Options_0000.json
# loaded document from Benefit_Options_0001.json
# loaded document from Benefit_Options_0002.json
# loaded document from Benefit_Options_0003.json
# loaded document from Benefit_Options_0004.json
# loaded document from dometic_fridge_stove_Sept 2025 20250918_114057_0000.json
# loaded document from dometic_fridge_stove_Sept 2025 20250918_114057_0001.json
# loaded document from dometic_fridge_stove_Sept 2025 20250918_114057_0002.json
# loaded document from employee_handbook_0000.json
# loaded document from employee_handbook_0001.json
# loaded document from employee_handbook_0002.json
# loaded document from employee_handbook_0003.json
# loaded document from employee_handbook_0004.json
# loaded document from employee_handbook_0005.json
# loaded document from employee_handbook_0006.json
# loaded document from employee_handbook_0007.json
# loaded document from employee_handbook_0008.json
# loaded document from employee_handbook_0009.json
# loaded document from employee_handbook_0010.json
# loaded document from employee_handbook_0011.json
# loaded document from employee_handbook_0012.json
# loaded document from employee_handbook_0013.json
# loaded document from employee_handbook_0014.json
# loaded document from employee_handbook_0015.json
# loaded document from employee_handbook_0016.json
# loaded document from employee_handbook_0017.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0000.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0001.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0002.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0003.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0004.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0005.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0006.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0007.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0008.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0009.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0010.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0011.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0012.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0013.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0014.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0015.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0016.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0017.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0018.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0019.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0020.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0021.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0022.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0023.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0024.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0025.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0026.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0027.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0028.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0029.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0030.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0031.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0032.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0033.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0034.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0035.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0036.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0037.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0038.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0039.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0040.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0041.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0042.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0043.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0044.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0045.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0046.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0047.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0048.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0049.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0050.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0051.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0052.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0053.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0054.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0055.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0056.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0057.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0058.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0059.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0060.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0061.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0062.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0063.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0064.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0065.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0066.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0067.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0068.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0069.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0070.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0071.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0072.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0073.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0074.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0075.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0076.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0077.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0078.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0079.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0080.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0081.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0082.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0083.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0084.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0085.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0086.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0087.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0088.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0089.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0090.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0091.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0092.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0093.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0094.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0095.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0096.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0097.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0098.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0099.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0100.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0101.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0102.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0103.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0104.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0105.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0106.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0107.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0108.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0109.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0110.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0111.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0112.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0113.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0114.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0115.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0116.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0117.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0118.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0119.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0120.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0121.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0122.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0123.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0124.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0125.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0126.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0127.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0128.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0129.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0130.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0131.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0132.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0133.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0134.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0135.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0136.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0137.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0138.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0139.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0140.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0141.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0142.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0143.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0144.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0145.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0146.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0147.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0148.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0149.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0150.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0151.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0152.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0153.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0154.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0155.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0156.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0157.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0158.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0159.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0160.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0161.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0162.json
# loaded document from Northwind_Health_Plus_Benefits_Details_0163.json
# loaded document from Northwind_Standard_Benefits_Details_0000.json
# loaded document from Northwind_Standard_Benefits_Details_0001.json
# loaded document from Northwind_Standard_Benefits_Details_0002.json
# loaded document from Northwind_Standard_Benefits_Details_0003.json
# loaded document from Northwind_Standard_Benefits_Details_0004.json
# loaded document from Northwind_Standard_Benefits_Details_0005.json
# loaded document from Northwind_Standard_Benefits_Details_0006.json
# loaded document from Northwind_Standard_Benefits_Details_0007.json
# loaded document from Northwind_Standard_Benefits_Details_0008.json
# loaded document from Northwind_Standard_Benefits_Details_0009.json
# loaded document from Northwind_Standard_Benefits_Details_0010.json
# loaded document from Northwind_Standard_Benefits_Details_0011.json
# loaded document from Northwind_Standard_Benefits_Details_0012.json
# loaded document from Northwind_Standard_Benefits_Details_0013.json
# loaded document from Northwind_Standard_Benefits_Details_0014.json
# loaded document from Northwind_Standard_Benefits_Details_0015.json
# loaded document from Northwind_Standard_Benefits_Details_0016.json
# loaded document from Northwind_Standard_Benefits_Details_0017.json
# loaded document from Northwind_Standard_Benefits_Details_0018.json
# loaded document from Northwind_Standard_Benefits_Details_0019.json
# loaded document from Northwind_Standard_Benefits_Details_0020.json
# loaded document from Northwind_Standard_Benefits_Details_0021.json
# loaded document from Northwind_Standard_Benefits_Details_0022.json
# loaded document from Northwind_Standard_Benefits_Details_0023.json
# loaded document from Northwind_Standard_Benefits_Details_0024.json
# loaded document from Northwind_Standard_Benefits_Details_0025.json
# loaded document from Northwind_Standard_Benefits_Details_0026.json
# loaded document from Northwind_Standard_Benefits_Details_0027.json
# loaded document from Northwind_Standard_Benefits_Details_0028.json
# loaded document from Northwind_Standard_Benefits_Details_0029.json
# loaded document from Northwind_Standard_Benefits_Details_0030.json
# loaded document from Northwind_Standard_Benefits_Details_0031.json
# loaded document from Northwind_Standard_Benefits_Details_0032.json
# loaded document from Northwind_Standard_Benefits_Details_0033.json
# loaded document from Northwind_Standard_Benefits_Details_0034.json
# loaded document from Northwind_Standard_Benefits_Details_0035.json
# loaded document from Northwind_Standard_Benefits_Details_0036.json
# loaded document from Northwind_Standard_Benefits_Details_0037.json
# loaded document from Northwind_Standard_Benefits_Details_0038.json
# loaded document from Northwind_Standard_Benefits_Details_0039.json
# loaded document from Northwind_Standard_Benefits_Details_0040.json
# loaded document from Northwind_Standard_Benefits_Details_0041.json
# loaded document from Northwind_Standard_Benefits_Details_0042.json
# loaded document from Northwind_Standard_Benefits_Details_0043.json
# loaded document from Northwind_Standard_Benefits_Details_0044.json
# loaded document from Northwind_Standard_Benefits_Details_0045.json
# loaded document from Northwind_Standard_Benefits_Details_0046.json
# loaded document from Northwind_Standard_Benefits_Details_0047.json
# loaded document from Northwind_Standard_Benefits_Details_0048.json
# loaded document from Northwind_Standard_Benefits_Details_0049.json
# loaded document from Northwind_Standard_Benefits_Details_0050.json
# loaded document from Northwind_Standard_Benefits_Details_0051.json
# loaded document from Northwind_Standard_Benefits_Details_0052.json
# loaded document from Northwind_Standard_Benefits_Details_0053.json
# loaded document from Northwind_Standard_Benefits_Details_0054.json
# loaded document from Northwind_Standard_Benefits_Details_0055.json
# loaded document from Northwind_Standard_Benefits_Details_0056.json
# loaded document from Northwind_Standard_Benefits_Details_0057.json
# loaded document from Northwind_Standard_Benefits_Details_0058.json
# loaded document from Northwind_Standard_Benefits_Details_0059.json
# loaded document from Northwind_Standard_Benefits_Details_0060.json
# loaded document from Northwind_Standard_Benefits_Details_0061.json
# loaded document from Northwind_Standard_Benefits_Details_0062.json
# loaded document from Northwind_Standard_Benefits_Details_0063.json
# loaded document from Northwind_Standard_Benefits_Details_0064.json
# loaded document from Northwind_Standard_Benefits_Details_0065.json
# loaded document from Northwind_Standard_Benefits_Details_0066.json
# loaded document from Northwind_Standard_Benefits_Details_0067.json
# loaded document from Northwind_Standard_Benefits_Details_0068.json
# loaded document from Northwind_Standard_Benefits_Details_0069.json
# loaded document from Northwind_Standard_Benefits_Details_0070.json
# loaded document from Northwind_Standard_Benefits_Details_0071.json
# loaded document from Northwind_Standard_Benefits_Details_0072.json
# loaded document from Northwind_Standard_Benefits_Details_0073.json
# loaded document from Northwind_Standard_Benefits_Details_0074.json
# loaded document from Northwind_Standard_Benefits_Details_0075.json
# loaded document from Northwind_Standard_Benefits_Details_0076.json
# loaded document from Northwind_Standard_Benefits_Details_0077.json
# loaded document from Northwind_Standard_Benefits_Details_0078.json
# loaded document from Northwind_Standard_Benefits_Details_0079.json
# loaded document from Northwind_Standard_Benefits_Details_0080.json
# loaded document from Northwind_Standard_Benefits_Details_0081.json
# loaded document from Northwind_Standard_Benefits_Details_0082.json
# loaded document from Northwind_Standard_Benefits_Details_0083.json
# loaded document from Northwind_Standard_Benefits_Details_0084.json
# loaded document from Northwind_Standard_Benefits_Details_0085.json
# loaded document from Northwind_Standard_Benefits_Details_0086.json
# loaded document from Northwind_Standard_Benefits_Details_0087.json
# loaded document from Northwind_Standard_Benefits_Details_0088.json
# loaded document from Northwind_Standard_Benefits_Details_0089.json
# loaded document from Northwind_Standard_Benefits_Details_0090.json
# loaded document from Northwind_Standard_Benefits_Details_0091.json
# loaded document from Northwind_Standard_Benefits_Details_0092.json
# loaded document from Northwind_Standard_Benefits_Details_0093.json
# loaded document from Northwind_Standard_Benefits_Details_0094.json
# loaded document from Northwind_Standard_Benefits_Details_0095.json
# loaded document from Northwind_Standard_Benefits_Details_0096.json
# loaded document from Northwind_Standard_Benefits_Details_0097.json
# loaded document from Northwind_Standard_Benefits_Details_0098.json
# loaded document from Northwind_Standard_Benefits_Details_0099.json
# loaded document from Northwind_Standard_Benefits_Details_0100.json
# loaded document from Northwind_Standard_Benefits_Details_0101.json
# loaded document from Northwind_Standard_Benefits_Details_0102.json
# loaded document from Northwind_Standard_Benefits_Details_0103.json
# loaded document from Northwind_Standard_Benefits_Details_0104.json
# loaded document from Northwind_Standard_Benefits_Details_0105.json
# loaded document from Northwind_Standard_Benefits_Details_0106.json
# loaded document from Northwind_Standard_Benefits_Details_0107.json
# loaded document from Northwind_Standard_Benefits_Details_0108.json
# loaded document from Northwind_Standard_Benefits_Details_0109.json
# loaded document from Northwind_Standard_Benefits_Details_0110.json
# loaded document from Northwind_Standard_Benefits_Details_0111.json
# loaded document from Northwind_Standard_Benefits_Details_0112.json
# loaded document from Northwind_Standard_Benefits_Details_0113.json
# loaded document from Northwind_Standard_Benefits_Details_0114.json
# loaded document from Northwind_Standard_Benefits_Details_0115.json
# loaded document from Northwind_Standard_Benefits_Details_0116.json
# loaded document from Northwind_Standard_Benefits_Details_0117.json
# loaded document from Northwind_Standard_Benefits_Details_0118.json
# loaded document from Northwind_Standard_Benefits_Details_0119.json
# loaded document from Northwind_Standard_Benefits_Details_0120.json
# loaded document from Northwind_Standard_Benefits_Details_0121.json
# loaded document from Northwind_Standard_Benefits_Details_0122.json
# loaded document from Northwind_Standard_Benefits_Details_0123.json
# loaded document from Northwind_Standard_Benefits_Details_0124.json
# loaded document from Northwind_Standard_Benefits_Details_0125.json
# loaded document from Northwind_Standard_Benefits_Details_0126.json
# loaded document from Northwind_Standard_Benefits_Details_0127.json
# loaded document from Northwind_Standard_Benefits_Details_0128.json
# loaded document from Northwind_Standard_Benefits_Details_0129.json
# loaded document from Northwind_Standard_Benefits_Details_0130.json
# loaded document from Northwind_Standard_Benefits_Details_0131.json
# loaded document from Northwind_Standard_Benefits_Details_0132.json
# loaded document from Northwind_Standard_Benefits_Details_0133.json
# loaded document from Northwind_Standard_Benefits_Details_0134.json
# loaded document from Northwind_Standard_Benefits_Details_0135.json
# loaded document from Northwind_Standard_Benefits_Details_0136.json
# loaded document from Northwind_Standard_Benefits_Details_0137.json
# loaded document from Northwind_Standard_Benefits_Details_0138.json
# loaded document from Northwind_Standard_Benefits_Details_0139.json
# loaded document from Northwind_Standard_Benefits_Details_0140.json
# loaded document from Northwind_Standard_Benefits_Details_0141.json
# loaded document from Northwind_Standard_Benefits_Details_0142.json
# loaded document from Northwind_Standard_Benefits_Details_0143.json
# loaded document from Northwind_Standard_Benefits_Details_0144.json
# loaded document from Northwind_Standard_Benefits_Details_0145.json
# loaded document from Northwind_Standard_Benefits_Details_0146.json
# loaded document from Northwind_Standard_Benefits_Details_0147.json
# loaded document from Northwind_Standard_Benefits_Details_0148.json
# loaded document from Northwind_Standard_Benefits_Details_0149.json
# loaded document from Northwind_Standard_Benefits_Details_0150.json
# loaded document from Northwind_Standard_Benefits_Details_0151.json
# loaded document from Northwind_Standard_Benefits_Details_0152.json
# loaded document from Northwind_Standard_Benefits_Details_0153.json
# loaded document from Northwind_Standard_Benefits_Details_0154.json
# loaded document from Northwind_Standard_Benefits_Details_0155.json
# loaded document from Northwind_Standard_Benefits_Details_0156.json
# loaded document from Northwind_Standard_Benefits_Details_0157.json
# loaded document from Northwind_Standard_Benefits_Details_0158.json
# loaded document from Northwind_Standard_Benefits_Details_0159.json
# loaded document from Northwind_Standard_Benefits_Details_0160.json
# loaded document from Northwind_Standard_Benefits_Details_0161.json
# loaded document from PerksPlus_0000.json
# loaded document from PerksPlus_0001.json
# loaded document from PerksPlus_0002.json
# loaded document from PerksPlus_0003.json
# <class 'list'>

# %%
print(len(documents))

# print(json.dumps(documents[0], indent=2))

print(documents[5])
# Out:
# 356
# {'chunk_id': 'dometic_fridge_stove_Sept_2025_20250918_114057_0000', 'file_name': './data/documents\\dometic_fridge_stove_Sept 2025 20250918_114057.pdf', 'base_name': 'dometic_fridge_stove_Sept 2025 20250918_114057.md', 'content': '<figure>  \nDOMETIC  \n</figure>', 'content_vector': [0.0030515885446220636, 0.00674192700535059, -0.04250023514032364, -0.0024732083547860384, -0.030504202470183372, 0.02212255634367466, -0.022870361804962158, 0.010967803187668324, 0.001612453954294324, -0.02481777034699917, 0.018866490572690964, -0.04605230689048767, 0.019583135843276978, -0.00475557055324316, 0.031049475073814392, 0.040319137275218964, -0.021997923031449318, 0.02607969008386135, -0.0027847937308251858, 0.07939193397760391, 0.030613256618380547, 0.005382636096328497, 0.0060875979252159595, -0.021873287856578827, -0.00931640062481165, 0.003879236988723278, -0.043746575713157654, 0.055244073271751404, 0.042593710124492645, -0.02782456763088703, -0.02017514780163765, -0.07951656728982925, 0.06275328248739243, -0.03100273758172989, 0.04832687973976135, 0.03343310207128525, 0.001869511790573597, 0.03595694527029991, -0.06353224068880081, -0.00997851975262165, -0.0028646374121308327, -0.026640543714165688, 0.0668662041425705, 0.01136507373303175, -0.03527145832777023, 0.014286186546087265, -0.01922481320798397, -0.029289018362760544, 0.01536115538328886, -0.033993955701589584, 0.057580966502428055, -0.014099234715104103, 0.03393163904547691, -0.008459541015326977, -0.007357308175414801, 0.005686431657522917, -0.03894816339015961, 0.037203285843133926, 0.03185959905385971, 0.02110990509390831, 0.0015189783880487084, -0.024661976844072342, 0.046519685536623, 0.029771976172924042, 0.015641583129763603, 0.03221791982650757, -0.022621093317866325, 0.018773015588521957, -0.02729487232863903, -0.06630535423755646, 0.045273344963788986, 0.01522873155772686, -0.0016377703286707401, -0.04327920079231262, 0.02271456830203533, -0.06823718547821045, -0.01733972318470478, -0.003703970229253173, -0.020253045484423637, -0.06365688145160675, -0.026142006739974022, 0.04112926125526428, -0.04377773404121399, -0.011622131802141666, -0.05636578053236008, -0.014099234715104103, -0.05692663416266441, 0.008155745454132557, -0.02609526924788952, -0.007014564238488674, -0.013117741793394089, -0.009721461683511734, -0.01113138534128666, -0.013335851021111012, -0.004778939764946699, 0.010632848367094994, -0.03274761512875557, -0.03037956729531288, -0.02749740332365036, -0.02076716162264347, 0.02206023968756199, -0.04966669902205467, 0.03039514645934105, 0.020268624648451805, 0.03548956662416458, -0.0015403998550027609, -0.005441058427095413, -0.017059296369552612, 0.012486780993640423, 0.014644509181380272, -0.050258710980415344, -0.051131147891283035, -0.022029081359505653, -0.0006923035834915936, 0.0003093944687861949, 0.014278396964073181, 0.01045368704944849, -0.009534510783851147, -0.002077884506434202, -0.033308468759059906, -0.013398168608546257, -0.01283731497824192, 0.029958928003907204, -0.045616090297698975, -0.010352421551942825, 0.03633084520697594, -0.034523651003837585, -0.006231706123799086, -0.01977008767426014, -0.05558681860566139, 0.027216976508498192, -0.0342743843793869, 0.04972901567816734, -0.04334151744842529, -0.01816542260348797, 0.02441270835697651, -0.011256019584834576, 0.015727268531918526, -0.01849258877336979, 0.047174014151096344, 0.04455669969320297, -0.04570956528186798, 0.0868699848651886, 0.05007175728678703, -0.012299830093979836, 0.013733122497797012, -0.028214050456881523, -0.025160513818264008, -0.019785666838288307, 0.003096379106864333, -0.0278401467949152, -0.020003776997327805, -0.015844112262129784, -0.01666981354355812, 0.012089509516954422, 0.005219053942710161, -0.0038987111765891314, 0.01230761967599392, -0.003594915382564068, 0.015820743516087532, 0.0018626959063112736, -0.010944433510303497, -0.013133320957422256, -0.01244004350155592, -0.03536493331193924, 0.06923425197601318, -0.018944386392831802, -0.005367056 ...

# %%
from azure.search.documents import SearchIndexingBufferedSender
import time
from tqdm import tqdm

# use tqdm to show progress bar
with tqdm(total=len(documents), desc="Uploading documents", unit="document") as pbar:
    # https://learn.microsoft.com/en-us/rest/api/searchservice/addupdate-or-delete-documents#request-body
# Use SearchIndexingBufferedSender to upload the documents in batches optimized for indexing
    with SearchIndexingBufferedSender(
        endpoint=endpoint,
        index_name=index_name,
        credential=credential,
    ) as batch_client:
        # Add upload actions for all documents
        for document in documents:
            batch_client.merge_or_upload_documents(documents=[document])
            # insert a wait for 1 sec
            time.sleep(1)
            pbar.update(1)
    print(f"Uploaded {len(documents)} documents in total")
# Out:
# Uploading documents: 100%|██████████| 356/356 [05:57<00:00,  1.00s/document]
# Uploaded 356 documents in total

# %%
from azure.search.documents.indexes import SearchIndexClient

client = SearchIndexClient(endpoint=endpoint, credential=credential)

# %%
index = client.get_index(index_name)

# %%
for field in index.fields:
    print(f"{field.name}: {field.type}")
# Out:
# chunk_id: Edm.String
# file_name: Edm.String
# base_name: Edm.String
# content: Edm.String
# content_vector: Collection(Edm.Single)

# %%
index_statistics = client.get_index_statistics(index_name)
print(f"Document count: {index_statistics}")
# Out:
# Document count: {'document_count': 356, 'storage_size': 7680619, 'vector_index_size': 6625676}
